# %% [markdown]
# [PMID: 37843832](https://pubmed.ncbi.nlm.nih.gov/37843832/)
#
#  **depleted innate and/or adaptive CD8+ lymphocytes in macaques**
#
#  PMCID: PMC10579699 (available on 2024-04-16) 真难受2024年3月6日16:31:34
#
#  treatment: CD8a,CD8b,IgG
#
#  看不了文献,不知道时怎么清除CD8的

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import scanpy as sc

from IPython.display import display
p_link = Path('/public/workspace/licanchengup/link')
p_disease = p_link.joinpath('disease')
p_test = p_link.joinpath('test')
p_data = p_disease.joinpath('dataset')

# %%
import sys
sys.path.append(str(p_test))

# %%
from func import group_agg, help_func,h5ad_to_mtx
help_func()
# Out:
# [func]----------------------------------
# group_agg
# rm_rf
# get_path_varmap
# get_type_counts_info		aligned
# aligned_type			aligned
# test_came_and_csMAHN
# h5ad_to_mtx
# load_adata
#
# [result tools]--------------------------
# get_test_result_df
# show_umap
# get_res_obs
# get_publi_head
#
# [result tools][re plot umap]-----------
# get_df_color			Convenient
# > [dssp umap]
# export_legend
# dssp_plot_umap_legend_sp	Convenient
# dssp_plot_umap_legend_cell_type	Convenient
# dssp_plot_umap
# dssp_get_umap_name
# dssp_plot_save_umap		Convenient
# > [umap]
# get_default_df_color
# plot_umap
# get_umap_name
# plot_save_umap			Convenient
# ----------------------------------------

# %%
df_meta = pd.read_csv("formatted_metadata.csv", header=[0, 1], index_col=0)
df_meta.columns = [i[0] for i in df_meta.columns]

# print(*df_meta.columns, sep='\n')
# for i in df.columns:
# for i in 'treatment,tb_infection_dose,lung_region'.split(','):
#     print('\n',i.ljust(70,'-'))
#     display(df_meta[i].value_counts())
df_meta = df_meta.loc[:,
                      'species__ontology_label,disease__ontology_label,organ__ontology_label,General_Celltypes,treatment,tb_infection_dose,CFU_TB_per_granuloma,total_thoracic_CFU,lung_region'.split(',')]

df_meta = df_meta.rename(
    columns={
        'species__ontology_label': 'species',
        'disease__ontology_label': 'disease',
        'organ__ontology_label': 'organ'})
display(df_meta.head(), df_meta.shape)
# Out:
#                                        species       disease organ  \
# Array2_28918_CAACGACACATC  Macaca fascicularis  tuberculosis  lung
# Array2_28918_CAGTATGAGATC  Macaca fascicularis  tuberculosis  lung
# Array2_28918_ACGTCGTCCCTT  Macaca fascicularis  tuberculosis  lung
# Array2_28918_GCCAGCACATTA  Macaca fascicularis  tuberculosis  lung
# Array2_28918_CGAGTCTGTTAG  Macaca fascicularis  tuberculosis  lung
#
#                                General_Celltypes treatment  tb_infection_dose  \
# Array2_28918_CAACGACACATC  Macrophages/Monocytes      CD8a                 19
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes      CD8a                 19
# Array2_28918_ACGTCGTCCCTT  Macrophages/Monocytes      CD8a                 19
# Array2_28918_GCCAGCACATTA  Macrophages/Monocytes      CD8a                 19
# Array2_28918_CGAGTCTGTTAG  Macrophages/Monocytes      CD8a                 19
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
# Array2_28918_ACGTCGTCCCTT                   580             5301080
# Array2_28918_GCCAGCACATTA                   580             5301080
# Array2_28918_CGAGTCTGTTAG                   580             5301080
#
#                           lung_region
# Array2_28918_CAACGACACATC         ACC
# Array2_28918_CAGTATGAGATC         ACC
# Array2_28918_ACGTCGTCCCTT         ACC
# Array2_28918_GCCAGCACATTA         ACC
# Array2_28918_CGAGTCTGTTAG         ACC
# (41976, 9)

# %% [markdown]
# |||
# |:-|:-|
# |species__ontology_label|Macaca fascicularis|
# |disease__ontology_label|tuberculosis|
# |library_preparation_protocol__ontology_label|Seq-Well S3|
# |organ__ontology_label|lung|
# |sex|unknown|
#
#
# treatment,tb_infection_dose,CFU_TB_per_granuloma,total_thoracic_CFU,lung_region
#
# CFU_TB_per_granuloma 各个肉芽肿的TB 的CFU
#
# total_thoracic_CFU   整个胸廓的TB 的CFU
#
# lung_region
#
# |  ||  |
# | :--: | :--: | :--: |
# | 右肺下叶 | RLL | Right Lower Lung |
# | 左肺下叶 | LLL | Left Lower Lung |
# | 肺尖 | ACC | Apex of Chest |
# | 右肺上叶 | RUL | Right Upper Lung |
# | 左肺上叶 | LUL | Left Upper Lung |
# | 左肺中叶 | LML | Left Middle Lung |

# %%
adata = sc.read_csv("UMI_counts_unfiltered.csv.gz").T
adata
# Out:
# AnnData object with n_obs × n_vars = 52563 × 31657

# %% [markdown]
# > h5ad 中不是count
#
# ```python
# adata = sc.read_h5ad("all_cells.h5ad")
# adata = sc.read_h5ad("all_cells.h5ad")
# display(adata.obs.head(2),adata.obs.shape,adata.var.head(2),adata.var.shape)
# adata.obs.to_csv('all_cells_obs.csv',index=True)
# temp = adata.X[:100,:100]
# temp[temp > 0]
# # array([0.63858855, 1.007928  , 0.7136451 , ..., 1.1508739 , 0.70140564,
# #        0.34567025], dtype=float32)
# ```

# %%
df_obs = pd.read_csv('all_cells_obs.csv', index_col=0)
# Gran State --?
# print(*df_obs.columns,sep='\n')
# display(df_obs[''].value_counts())
df_obs = df_obs.loc[:,
                    'batch,treatment,infection dose,lung region,CFU/granuloma,total thoracic CFU,General Celltypes'.split(',')]
df_obs = df_obs.rename(columns={'CFU/granuloma': 'CFU_TB_per_granuloma',
                       'General Celltypes': 'General_Celltypes',
                       'infection dose': 'tb_infection_dose',
                       'lung region': 'lung_region',
                       'total thoracic CFU': 'total_thoracic_CFU'})
display(df_obs.head(2), df_obs.shape,
        pd.Series(adata.obs.index.isin(df_obs.index)).value_counts())
# Out:
#                            batch treatment  tb_infection_dose lung_region  \
# NAME
# Array2_28918_CAACGACACATC      0      CD8a                 19         ACC
# Array2_28918_CAGTATGAGATC      0      CD8a                 19         ACC
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# NAME
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
#
#                                General_Celltypes
# NAME
# Array2_28918_CAACGACACATC  Macrophages/Monocytes
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes
# (41976, 7)
# True     41976
# False    10587
# Name: count, dtype: int64

# %%
display(df_obs.head(2), df_meta.head(2))
# Out:
#                            batch treatment  infection dose lung region  \
# Array2_28918_CAACGACACATC      0      CD8a              19         ACC
# Array2_28918_CAGTATGAGATC      0      CD8a              19         ACC
#
#                            CFU/granuloma  total thoracic CFU  \
# Array2_28918_CAACGACACATC            580             5301080
# Array2_28918_CAGTATGAGATC            580             5301080
#
#                                General Celltypes
# Array2_28918_CAACGACACATC  Macrophages/Monocytes
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes
#                                        species       disease organ  \
# Array2_28918_CAACGACACATC  Macaca fascicularis  tuberculosis  lung
# Array2_28918_CAGTATGAGATC  Macaca fascicularis  tuberculosis  lung
#
#                                General_Celltypes treatment  tb_infection_dose  \
# Array2_28918_CAACGACACATC  Macrophages/Monocytes      CD8a                 19
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes      CD8a                 19
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
#
#                           lung_region
# Array2_28918_CAACGACACATC         ACC
# Array2_28918_CAGTATGAGATC         ACC

# %%
# Out:
# Index(['batch', 'treatment', 'tb_infection_dose', 'lung_region',
#        'CFU_TB_per_granuloma', 'total_thoracic_CFU', 'General_Celltypes'],
#       dtype='object')

# %%
# Out:
# df_obs == df_meta all True key CFU_TB_per_granuloma
# df_obs == df_meta all True key General_Celltypes
# df_obs == df_meta all True key lung_region
# df_obs == df_meta all True key tb_infection_dose
# df_obs == df_meta all True key total_thoracic_CFU
# df_obs == df_meta all True key treatment

# %%
# Out:
#                            batch treatment  tb_infection_dose lung_region  \
# Array2_28918_CAACGACACATC      0      CD8a                 19         ACC
# Array2_28918_CAGTATGAGATC      0      CD8a                 19         ACC
# Array2_28918_ACGTCGTCCCTT      0      CD8a                 19         ACC
# Array2_28918_GCCAGCACATTA      0      CD8a                 19         ACC
# Array2_28918_CGAGTCTGTTAG      0      CD8a                 19         ACC
# ...                          ...       ...                ...         ...
# Array9_29618_CCGAAATCTAGT     49       IgG                 23         LLL
# Array9_29618_ATGCAGACGTCG     49       IgG                 23         LLL
# Array9_29618_AACTTTAAGCAC     49       IgG                 23         LLL
# Array9_29618_AGCTCCGAAGTC     49       IgG                 23         LLL
# Array9_29618_CCTGGGTTTCTC     49       IgG                 23         LLL
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
# Array2_28918_ACGTCGTCCCTT                   580             5301080
# Array2_28918_GCCAGCACATTA                   580             5301080
# Array2_28918_CGAGTCTGTTAG                   580             5301080
# ...                                         ...                 ...
# Array9_29618_CCGAAATCTAGT                618000             4976735
# Array9_29618_ATGCAGACGTCG                618000             4976735
# Array9_29618_AACTTTAAGCAC                618000             4976735
# Array9_29618_AGCTCCGAAGTC                618000             4976735
# Array9_29618_CCTGGGTTTCTC                618000             4976735
#
#                                General_Celltypes       disease organ  \
# Array2_28918_CAACGACACATC  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_ACGTCGTCCCTT  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_GCCAGCACATTA  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_CGAGTCTGTTAG  Macrophages/Monocytes  tuberculosis  lung
# ...                                          ...           ...   ...
# Array9_29618_CCGAAATCTAGT                   T/NK  tuberculosis  lung
# Array9_29618_ATGCAGACGTCG                   T/NK  tuberculosis  lung
# Array9_29618_AACTTTAAGCAC                   T/NK  tuberculosis  lung
# Array9_29618_AGCTCCGAAGTC                   T/NK  tuberculosis  lung
# Array9_29618_CCTGGGTTTCTC                   T/NK  tuberculosis  lung
#
#                                        species
# Array2_28918_CAACGACACATC  Macaca fascicularis
# Array2_28918_CAGTATGAGATC  Macaca fascicularis
# Array2_28918_ACGTCGTCCCTT  Macaca fascicularis
# Array2_28918_GCCAGCACATTA  Macaca fascicularis
# Array2_28918_CGAGTCTGTTAG  Macaca fascicularis
# ...                                        ...
# Array9_29618_CCGAAATCTAGT  Macaca fascicularis
# Array9_29618_ATGCAGACGTCG  Macaca fascicularis
# Array9_29618_AACTTTAAGCAC  Macaca fascicularis
# Array9_29618_AGCTCCGAAGTC  Macaca fascicularis
# Array9_29618_CCTGGGTTTCTC  Macaca fascicularis
#
# [41976 rows x 10 columns]

# %%
display(
    np.intersect1d(df_obs.columns, df_meta.columns),
    np.setdiff1d(df_obs.columns, df_meta.columns),
    np.setdiff1d(df_meta.columns, df_obs.columns)

)

df_obs = df_meta.loc[:, []].join(df_obs)
for i in np.intersect1d(df_obs.columns, df_meta.columns):
    print('df_obs == df_meta all {} key {} '.format((df_obs[i]==df_meta[i]).all(),i))

df_obs = df_obs.join(df_meta.loc[:,np.setdiff1d(df_meta.columns, df_obs.columns)])
display(df_obs.head(2),df_obs.shape)
# Out:
# array(['CFU_TB_per_granuloma', 'General_Celltypes', 'lung_region',
#        'tb_infection_dose', 'total_thoracic_CFU', 'treatment'],
#       dtype=object)
# array(['batch'], dtype=object)
# array(['disease', 'organ', 'species'], dtype=object)
# df_obs == df_meta all True key CFU_TB_per_granuloma
# df_obs == df_meta all True key General_Celltypes
# df_obs == df_meta all True key lung_region
# df_obs == df_meta all True key tb_infection_dose
# df_obs == df_meta all True key total_thoracic_CFU
# df_obs == df_meta all True key treatment
#                            batch treatment  tb_infection_dose lung_region  \
# Array2_28918_CAACGACACATC      0      CD8a                 19         ACC
# Array2_28918_CAGTATGAGATC      0      CD8a                 19         ACC
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
#
#                                General_Celltypes       disease organ  \
# Array2_28918_CAACGACACATC  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes  tuberculosis  lung
#
#                                        species
# Array2_28918_CAACGACACATC  Macaca fascicularis
# Array2_28918_CAGTATGAGATC  Macaca fascicularis
# (41976, 10)

# %%
display(adata.obs.head(2),adata.obs.shape,df_obs.head(2),df_obs.shape)
print('all of adata.obs.index is in df_obs.index\n{} '.format(df_obs.index.isin(adata.obs.index).all()))
# Out:
# Empty DataFrame
# Columns: []
# Index: [Array2_28918_TTTTTTTTTTTT, Array2_28918_CGTACATCGTTA]
# (52563, 0)
#                            batch treatment  tb_infection_dose lung_region  \
# Array2_28918_CAACGACACATC      0      CD8a                 19         ACC
# Array2_28918_CAGTATGAGATC      0      CD8a                 19         ACC
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
#
#                                General_Celltypes       disease organ  \
# Array2_28918_CAACGACACATC  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes  tuberculosis  lung
#
#                                        species
# Array2_28918_CAACGACACATC  Macaca fascicularis
# Array2_28918_CAGTATGAGATC  Macaca fascicularis
# (41976, 10)
# all of adata.obs.index is in df_obs.index
# True

# %%
display(adata.obs.shape)
adata = adata[adata.obs.index.isin(df_obs.index)]
adata.obs = adata.obs.loc[:,[]].join(df_obs)
display(adata.obs.shape,adata.obs.head(2))
# Out:
# (41976, 0)
# (41976, 10)
#                            batch treatment  tb_infection_dose lung_region  \
# Array2_28918_CAACGACACATC      0      CD8a                 19         ACC
# Array2_28918_CAGTATGAGATC      0      CD8a                 19         ACC
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
#
#                                General_Celltypes       disease organ  \
# Array2_28918_CAACGACACATC  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes  tuberculosis  lung
#
#                                        species
# Array2_28918_CAACGACACATC  Macaca fascicularis
# Array2_28918_CAGTATGAGATC  Macaca fascicularis

# %%
display(adata.obs.head(2))
group_agg(adata.obs,'disease,treatment,tb_infection_dose,batch'.split(','),{'batch':['count']},reindex=False)
# Out:
#                            batch treatment  tb_infection_dose lung_region  \
# Array2_28918_CAACGACACATC      0      CD8a                 19         ACC
# Array2_28918_CAGTATGAGATC      0      CD8a                 19         ACC
#
#                            CFU_TB_per_granuloma  total_thoracic_CFU  \
# Array2_28918_CAACGACACATC                   580             5301080
# Array2_28918_CAGTATGAGATC                   580             5301080
#
#                                General_Celltypes       disease organ  \
# Array2_28918_CAACGACACATC  Macrophages/Monocytes  tuberculosis  lung
# Array2_28918_CAGTATGAGATC  Macrophages/Monocytes  tuberculosis  lung
#
#                                        species
# Array2_28918_CAACGACACATC  Macaca fascicularis
# Array2_28918_CAGTATGAGATC  Macaca fascicularis
#                                                batch
#                                                count
# disease      treatment tb_infection_dose batch
# tuberculosis CD8a      18                2      1412
#                                          34     1207
#                                          42     1054
#                                          44     1119
#                        19                0       927
#                                          11      966
#                                          32      944
#                                          43      951
#                                          45     1148
#                        23                3      1140
#                                          6      1302
#                                          17      999
#                                          19      974
#                                          25     1179
#                                          30     1294
#                                          37     1127
#                                          47      895
#              CD8b      18                20     1125
#                                          27     1091
#                                          36     1204
#                                          41      983
#                        19                9       984
#                                          15      885
#                                          33      856
#                                          39      531
#                        23                7      1232
#                                          23     1185
#                                          29     1097
#                                          48     1230
#              IgG       18                8      1084
#                                          13     1015
#                                          35     1020
#                                          40      846
#                        23                4      1009
#                                          5       821
#                                          10      180
#                                          16     1143
#                                          22      827
#                                          31     1007
#                                          46      926
#                                          49     1057

# %%
h5ad_to_mtx(adata,'Mtb_macaca_del_CD8_SCP642')
# Out:
# frist 10 data.X nonzero elements:
#  [[3 2 1 5 2 7 2 7 1 1]]
# [out] Mtb_del_CD8_macaque
